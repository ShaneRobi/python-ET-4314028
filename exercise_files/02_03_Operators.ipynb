# %% [markdown]
# ## Arithmetic Operators

# %%
1 + 1
# Out:
# 2

# %%
4 * 5
# Out:
# 20

# %%
5 ** 2
# Out:
# 25

# %%
20 / 5
# Out:
# 4.0

# %%
20 / 6
# Out:
# 3.3333333333333335

# %%
20 % 6
# Out:
# 2

# %% [markdown]
# ### Arithmetic Operators with Strings

# %%
'string 1 ' + 'string 2'
# Out:
# 'string 1 string 2'

# %%
'- string 1 - ' * 4
# Out:
# '- string 1 - - string 1 - - string 1 - - string 1 - '

# %%
' 1' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 ' 1' + 4
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Comparison, Logical, and Membership Operators

# %% [markdown]
# ### Comparison Operators

# %%
True == True
# Out:
# True

# %%
4 < 5
# Out:
# True

# %%
5 <= 5
# Out:
# True

# %%
5 > 2
# Out:
# True

# %%
5 >=2
# Out:
# True

# %% [markdown]
# ### Logical Operators (and, or, not)

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### Membership Operators

# %%
1 in [1,2,3,4,5]
# Out:
# True

# %%
10 not in [1,2,3,4,5]
# Out:
# True

# %%
'cat' not in 'my pet cat'
# Out:
# False

# %% [markdown]
# ## Shane's

# %%
1 + 1
# Out:
# 2

# %%
4 * 5
# Out:
# 20

# %%
5 ** 2
#exponent 5 raised to the 2nd power
# Out:
# 25

# %%
20 / 5
# Out:
# 4.0

# %%
20/6
# Out:
# 3.3333333333333335

# %%
#modulus gives you back the reminder
20 % 6
# Out:
# 2

# %% [markdown]
# ## Arithmethic operator with strings

# %%
'string 1' + 'String 2'
# Out:
# 'string 1String 2'

# %%
'- string 1 -' * 4
# Out:
# '- string 1 -- string 1 -- string 1 -- string 1 -'

# %% [markdown]
# ### comparison, logic and membership operator

# %% [markdown]
# ### Comparison operators

# %%
True == True
# Out:
# True

# %%
4 < 5
# Out:
# True

# %%
5 <= 5
# Out:
# True

# %%
5 > 2
# Out:
# True

# %%
5 >= 2
# Out:
# True

# %% [markdown]
# ### Logic operators (and, or, not)

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### Memebership operators (in, or not in)

# %%
1 in [1,2,3,4,5,6]
# Out:
# True

# %%
10 in [1,2,3,4,5]
# Out:
# False

# %%
10 not in [1,2,3,4]
# Out:
# True

# %%
'cat' in 'my pet cat'
# Out:
# True

# %%
'cat' not in 'my pet cat'
# Out:
# False
