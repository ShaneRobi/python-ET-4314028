# %% [markdown]
# # Title
# ## smaller title

# %% [markdown]
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %% [markdown]
# Some text

# %%
print(1 + 1)
# Out:
# 2

# %%
print("doing some work now")
# Out:
# doing some work now
